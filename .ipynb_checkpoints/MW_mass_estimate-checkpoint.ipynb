# %%
import pandas as pd
import numpy as np

# %%
callingham_masses = pd.read_csv('./Data/midpoints_bot2top.csv',header= None,names = [r'Mass',r'$M_{200}$ $(10^{12} M_\odot)$'])
callingham_masses
# Out:
#         Mass  $M_{200}$ $(10^{12} M_\odot)$
# 0   1.176982                       0.063232
# 1   1.039253                       0.964871
# 2   1.118166                       0.087432
# 3   0.691968                       0.098361
# 4   0.663757                       0.109290
# 5   1.594699                       0.121780
# 6   0.747106                       0.133489
# 7   1.420823                       0.209212
# 8   1.771700                       0.220921
# 9   0.778585                       0.232631
# 10  0.693861                       0.244340
# 11  0.766173                       0.256050
# 12  1.146492                       0.267760
# 13  1.406939                       0.278689
# 14  0.808906                       0.290398
# 15  1.319370                       0.366120
# 16  1.573129                       0.378610
# 17  2.574080                       0.454333
# 18  1.297827                       0.512100
# 19  0.998328                       0.523029
# ...

# %%
mean_mass = callingham_masses.Mass.mean()
print(r'Mean Mass for these sources : M_200 = {:.2f} x 10^12 M_sol'.format(mean_mass))
# Out:
# Mean Mass for these sources : M_200 = 1.18 x 10^12 M_sol

# %% [markdown]
# So, if we just take a blind average of these values, we get that **M<sub>200</sub><sup>MW</sup> = 1.18 x 10<sup>12</sup> M<sub></sub>**
